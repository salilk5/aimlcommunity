# %% [markdown]
# **Step 1: Open the file in your python notebook, print first 5 rows of the dataset and mention what are the dependent and independent variables in the Data**

# %%
import pandas as pd

df = pd.read_excel("Wisconsin.xlsx")

df.head(5)


Dependent variable   : Diagnosis
Independent variable  : Remaining variables

# %% [markdown]
# **Step 2: Find the statistical parameters of the Data that you have**

# %%
import pandas as pd

df = pd.read_excel("Wisconsin.xlsx")

df.info()

# %% [markdown]
# **Step 3: Find the shape of the Dataset in hand**

# %%
import pandas as pd

df = pd.read_excel("Wisconsin.xlsx")

sh = df.shape

sh

# %% [markdown]
# **Step 4: Find missing values from the Dataset**

# %%
import pandas as pd

df = pd.read_excel("Wisconsin.xlsx")

df.isnull().sum()

# %% [markdown]
# **Step 5: Find the value count of B(Benign) and M(Malignant) cancer cells in the column "diagnosis**

# %%
import pandas as pd

df = pd.read_excel("Wisconsin.xlsx")

df["diagnosis"].value_counts()

# %% [markdown]
# **Step 6: Creating a pairplot and mention the findings**

# %%
import pandas as pd

import seaborn as sns

df = pd.read_excel("Wisconsin.xlsx")

sns.pairplot(df[['id','diagnosis','radius_mean','texture_mean','perimeter_mean']],hue="diagnosis")

# %% [markdown]
# **Step 7: Create a correlation matrix and mention strongly, weakly and negatively correlated quantities.**

# %%
import pandas as pd
import seaborn as sns
df = pd.read_excel("Wisconsin.xlsx")
df.corr(method= "pearson")

VARIABLE	        STRONG  CORRELATION 	                            WEAK    CORRELATION 	                                              NEGATIVE  CORRELATION 
 	 	 	 
radius_mean	1) perimeter_mean                                       1)smoothness_mean                                                   1)fractal_dimension_mean        
            2)area_mean                                             2)symmetry_mean                                                     2)texxture_se
            3)radius_worst                                          3)smoohtness_worst                                                  3)symmetry_se
            4)area_worst                                            4)symmetry_worst                                                    4)fractal_dimension_se
            5)perimeter_worst	                                      5)fractal_dimension_worst
